# %% [markdown]
# # SPARQLing FAIRyland — map-ready SPARQL for QGIS
#
# *A SPARQLing Unicorn demonstration notebook (local Jupyter variant).*
#
# ## About this notebook
#
# Every query here follows the **SPARQLing Unicorn convention**: it binds **`?item`** (the
# main feature) and **`?geo`** (its `geo:asWKT` geometry), so each result **renders as a map
# here** and can be **pasted straight into the plugin’s query editor**
# (*Linked Data Processing → Concept Query*) to load as a QGIS vector layer. Optional
# `?itemLabel` (the find’s name) and `?layerLabel` (its class) come along as attributes you
# can style by in QGIS.
#
# The dataset is *FAIRyland — “The Lost Flat-Pack Civilisation of Norrfors”*, a wholly
# fictional GeoSPARQL excavation dataset (finds, trenches and periods are invented; only the
# geological dates are real).
#
# **What you’ll learn.** Four reusable, map-producing SPARQL patterns:
#
# 1. **all finds** with geometry, styled by class (`?layerLabel`);
# 2. the **trench plan** — the 30 trenches as polygons;
# 3. finds of a chosen **geological period**, via property-path roll-up (`hasperiod/skos:broader*`);
# 4. finds **within a chosen trench** (the GeoSPARQL `geof:sfWithin` form is noted for GeoSPARQL endpoints).
#
# **Data-context notes.** Coordinates use **CRS84** (lon, lat; WGS 84); geometries are points
# and polygons (finds, trenches) plus lines (baulk paths).
#
# **Tooling notes.** We query the Turtle file locally with **`rdflib`** — exactly what the
# SPARQLing Unicorn plugin does on a local `.ttl`. The `?item` + `?geo` binding is all the
# plugin needs to turn each row into a feature.
#
# > A browser-executable **`.qmd`** companion (Pyodide, no install) will accompany this in the OER.
#
# ### Requirements
#
# ```bash
# pip install rdflib shapely folium pandas
# ```

# %%
# --- Setup: imports, data source, graph, and a reusable map helper ---
import pandas as pd
from rdflib import Graph
from shapely import wkt as shapely_wkt
import folium

TTL_SOURCE = "fairyland.ttl"
TTL_URL    = "https://raw.githubusercontent.com/unicorn-demo/test1/main/fairyland.ttl"

g = Graph()
try:
    g.parse(TTL_SOURCE, format="turtle")
except Exception:
    g.parse(TTL_URL, format="turtle")

PFX = """PREFIX fairyland: <https://github.com/Research-Squirrel-Engineers/FAIRyland/>
PREFIX geo:  <http://www.opengis.net/ont/geosparql#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX suni: <http://www.github.com/sparqlunicorn#>"""

PALETTE = ["#8e44ad", "#2980b9", "#f39c12", "#c0392b", "#16a085", "#7f8c8d",
           "#27ae60", "#34495e", "#111111", "#e84393", "#00897b", "#d35400"]

def map_geo(query, colour_by=None, zoom=17, weight=2):
    """Run a SPARQL SELECT that binds ?item and ?geo (a WKT literal) and map every
    geometry. Points -> circle markers; polygons/lines -> outlines. If `colour_by` names
    another result column (e.g. 'layerLabel'), features are coloured by it with a legend."""
    res  = g.query(query)
    vrs  = [str(v) for v in res.vars]
    assert "geo" in vrs, "the query must bind a ?geo (WKT) column"
    rows = [{str(c): (None if r[c] is None else str(r[c])) for c in res.vars} for r in res]
    geoms = [(row, shapely_wkt.loads(row["geo"])) for row in rows]
    cs = [gm.centroid for _, gm in geoms]
    m = folium.Map(location=[sum(p.y for p in cs)/len(cs), sum(p.x for p in cs)/len(cs)],
                   zoom_start=zoom, tiles="OpenStreetMap")
    cmap = {}
    if colour_by:
        vals = sorted({row.get(colour_by) for row in rows if row.get(colour_by)})
        cmap = {val: PALETTE[i % len(PALETTE)] for i, val in enumerate(vals)}
    for row, gm in geoms:
        col = cmap.get(row.get(colour_by), "#8e44ad") if colour_by else "#8e44ad"
        popup = folium.Popup(" | ".join(f"{k}={row[k]}" for k in vrs if k != "geo"), max_width=260)
        if gm.geom_type in ("Polygon", "MultiPolygon"):
            for poly in ([gm] if gm.geom_type == "Polygon" else list(gm.geoms)):
                folium.Polygon([(y, x) for x, y in poly.exterior.coords], color=col,
                               weight=weight, fill=True, fill_opacity=0.15, popup=popup).add_to(m)
        elif gm.geom_type == "LineString":
            folium.PolyLine([(y, x) for x, y in gm.coords], color=col, weight=3).add_to(m)
        else:
            folium.CircleMarker([gm.centroid.y, gm.centroid.x], radius=4, color=col,
                                fill=True, fill_opacity=0.85, popup=popup).add_to(m)
    if cmap:
        legend = ("<div style='position:fixed;bottom:20px;left:20px;z-index:9999;background:white;"
                  "padding:8px 10px;border:1px solid #999;border-radius:4px;font:12px sans-serif'>"
                  f"<b>{colour_by}</b><br>"
                  + "".join(f"<span style='color:{c}'>●</span> {v}<br>" for v, c in cmap.items())
                  + "</div>")
        m.get_root().html.add_child(folium.Element(legend))
    return m

print(f"✓ Graph loaded: {len(g):,} triples. Every query below binds ?item + ?geo and maps.")
# Out:
# ✓ Graph loaded: 3,959 triples. Every query below binds ?item + ?geo and maps.

# %% [markdown]
# ## 1 — All finds, styled by class
#
# The overview layer. `?item` is the find, `?geo` its WKT geometry, `?layerLabel` its class
# (for category styling in QGIS), `?itemLabel` its name.

# %%
q_all = PFX + """
SELECT ?item ?itemLabel ?geo ?layerLabel WHERE {
  # ?item a ?cls .
  # ?cls  rdfs:subClassOf fairyland:Find ; rdfs:label ?layerLabel .
  OPTIONAL { ?item suni:Name ?itemLabel }
  # ?item geo:hasGeometry/geo:asWKT ?geo .
}"""
print(q_all)
map_geo(q_all, colour_by="layerLabel")
# Out:
# PREFIX fairyland: <https://github.com/Research-Squirrel-Engineers/FAIRyland/>
# PREFIX geo:  <http://www.opengis.net/ont/geosparql#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX suni: <http://www.github.com/sparqlunicorn#>
# SELECT ?item ?itemLabel ?geo ?layerLabel WHERE {
#   ?item a ?cls .
#   ?cls  rdfs:subClassOf fairyland:Find ; rdfs:label ?layerLabel .
#   OPTIONAL { ?item suni:Name ?itemLabel }
#   ?item geo:hasGeometry/geo:asWKT ?geo .
# }
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7d80ee16d4c24bed57c5ef3b5713312 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&#x27;position:fixed;bottom:20px;left:20px;z-index:9999;background:white;padding:8px 10px;border:1px solid #999;border-radius:4px;font:12px sans-serif&#x27;&gt;&lt;b&gt;layerLabel&lt;/b&gt;&lt;br&gt;&lt;span style=&#x27;color:#8e44ad&#x27;&gt;●&lt;/span&gt; Allen key&lt;br&gt;&lt;span style=&#x27;color:#2980b9&#x27;&gt;●&lt;/span&gt; Banana&lt;br&gt;&lt;span style=&#x27;color:#f39c12&#x27;&gt;●&lt;/span&gt; Crater&lt;br&gt;&lt;span style=&#x27;color:#c0392b&#x27;&gt;●&lt;/span&gt; Flat-pack panel&lt;br&gt;&lt;span style=&#x27;color:#16a085&#x27;&gt;●&lt;/span&gt; Kangaroo&lt;br&gt;&lt;span style=&#x27;color:#7f8c8d&#x27;&gt;●&lt;/span&gt; Koettbullar (meatball find)&lt;br&gt;&lt;span style=&#x27;color:#27ae60&#x27;&gt;●&lt;/span&gt; Lingonberry jar&lt;br&gt;&lt;span style=&#x27;color:#34495e&#x27;&gt;●&lt;/span&gt; Minion&lt;br&gt;&lt;span style=&#x27;color:#111111&#x27;&gt;●&lt;/span&gt; Pencil stub&lt;br&gt;&lt;span style=&#x27;color:#e84393&#x27;&gt;●&lt;/span&gt; Stone&lt;br&gt;&lt;span style=&#x27;color:#00897b&#x27;&gt;●&lt;/span&gt; Tea light&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7d80ee16d4c24bed57c5ef3b5713312&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7d80ee16d4c24bed57c5ef3b5713312 = L.map(
#                 &quot;map_e7d80ee16d4c24bed57c5ef3b5713312&quot;,
#                 {
#                     center: [63.880109204098375, 20.026409672814214],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_869261eda373bb1747c30397b1ca218e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_869261eda373bb1747c30397b1ca218e.addTo(map_e7d80ee16d4c24bed57c5ef3b5713312);
#
#
#             var polygon_d8189395e292e464a065af1d31b8b7c7 = L.polygon(
#                 [[63.880111, 20.028751], [63.880111, 20.0288041], [63.8801237, 20.0288041], [63.8801237, 20.028751], [63.880111, 20.028751]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e7d80ee16d4c24bed57c5ef3b5713312);
#
#
#         var popup_d5eea31853a5b9c4265107b5e3fde173 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_2f97a54e7fd0dd77f2cea08f47b112f6 = $(`&lt;div id=&quot;html_2f97a54e7fd0dd77f2cea08f47b112f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#86f8a06e-51c7-41be-935b-e70bfcaa67b7 | itemLabel=Allen key (Inbusschlüssel) | layerLabel=Allen key&lt;/div&gt;`)[0];
#                 popup_d5eea31853a5b9c4265107b5e3fde173.setContent(html_2f97a54e7fd0dd77f2cea08f47b112f6);
#
#
#
#         polygon_d8189395e292e464a065af1d31b8b7c7.bindPopup(popup_d5eea31853a5b9c4265107b5e3fde173)
#         ;
#
#
#
#
#             var polygon_12518324e32bfc4cbef1cd2490875c52 = L.polygon(
#                 [[63.8800796, 20.0237753], [63.8800796, 20.0238283], [63.8800923, 20.0238283], [63.8800923, 20.0237753], [63.8800796, 20.0237753]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f39c12&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f39c12&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e7d80ee16d4c24bed57c5ef3b5713312);
#
#
#         var popup_760a1e437cf63829fb6aeea10b4f3e79 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_a28840a57cb9e79564797a0945a752b7 = $(`&lt;div id=&quot;html_a28840a57cb9e79564797a0945a752b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#4db030c2-2331-4dad-b17c-da023bceff9f | itemLabel=Crater | layerLabel=Crater&lt;/div&gt;`)[0];

# %% [markdown]
# ## 2 — The trench plan
#
# The 30 trenches as **polygons** — a pure-geometry layer (`?item` = trench, `?geo` = its
# outline), ideal as a base "site plan" over a satellite basemap in QGIS.

# %%
q_trenches = PFX + """
SELECT ?item ?itemLabel ?geo WHERE {
  # ?item a fairyland:Trench ;
        rdfs:label ?itemLabel ;
        geo:hasGeometry/geo:asWKT ?geo .
}"""
print(q_trenches)
map_geo(q_trenches, zoom=16, weight=1)
# Out:
# PREFIX fairyland: <https://github.com/Research-Squirrel-Engineers/FAIRyland/>
# PREFIX geo:  <http://www.opengis.net/ont/geosparql#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX suni: <http://www.github.com/sparqlunicorn#>
# SELECT ?item ?itemLabel ?geo WHERE {
#   ?item a fairyland:Trench ;
#         rdfs:label ?itemLabel ;
#         geo:hasGeometry/geo:asWKT ?geo .
# }
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c608a52e0edd8946128a497dd48ae7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c608a52e0edd8946128a497dd48ae7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c608a52e0edd8946128a497dd48ae7f = L.map(
#                 &quot;map_1c608a52e0edd8946128a497dd48ae7f&quot;,
#                 {
#                     center: [63.88011660000002, 20.02645325],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f733bbf995f0ca23ea12f4a28e8e6606 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f733bbf995f0ca23ea12f4a28e8e6606.addTo(map_1c608a52e0edd8946128a497dd48ae7f);
#
#
#             var polygon_b6293ad4b9b02280f0528484f50bbe09 = L.polygon(
#                 [[63.88084, 20.025331], [63.881202, 20.025331], [63.881202, 20.024515], [63.88084, 20.024515], [63.88084, 20.025331]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1c608a52e0edd8946128a497dd48ae7f);
#
#
#         var popup_1bbfe6062356ef20da0f70c8408997ed = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_fe80d1e0343afeb67c841617a136b412 = $(`&lt;div id=&quot;html_fe80d1e0343afeb67c841617a136b412&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=https://github.com/Research-Squirrel-Engineers/FAIRyland/Trench_A2 | itemLabel=Trench A2&lt;/div&gt;`)[0];
#                 popup_1bbfe6062356ef20da0f70c8408997ed.setContent(html_fe80d1e0343afeb67c841617a136b412);
#
#
#
#         polygon_b6293ad4b9b02280f0528484f50bbe09.bindPopup(popup_1bbfe6062356ef20da0f70c8408997ed)
#         ;
#
#
#
#
#             var polygon_970c09566bc2ba475d23cbd1c41b1877 = L.polygon(
#                 [[63.88084, 20.026351], [63.881202, 20.026351], [63.881202, 20.025535], [63.88084, 20.025535], [63.88084, 20.026351]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1c608a52e0edd8946128a497dd48ae7f);
#
#
#         var popup_1a1de3efd46ca0a989843cb8b493f1d2 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_c37c46f08fb38b3c7a0f18c1b31e3620 = $(`&lt;div id=&quot;html_c37c46f08fb38b3c7a0f18c1b31e3620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=https://github.com/Research-Squirrel-Engineers/FAIRyland/Trench_A3 | itemLabel=Trench A3&lt;/div&gt;`)[0];
#                 popup_1a1de3efd46ca0a989843cb8b493f1d2.setContent(html_c37c46f08fb38b3c7a0f18c1b31e3620);
#
#
#
#         polygon_970c09566bc2ba475d23cbd1c41b1877.bindPopup(popup_1a1de3efd46ca0a989843cb8b493f1d2)
#         ;
#
#
#
#
#             var polygon_e8b47e6c6e213a537fe457759dcf592e = L.polygon(
#                 [[63.88084, 20.027371], [63.881202, 20.027371], [63.881202, 20.026555], [63.88084, 20.026555], [63.88084, 20.027371]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1c608a52e0edd8946128a497dd48ae7f);
#
#
#         var popup_268f1a5f38685c0b29a8f7509408b631 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_09584f206db0258d7ce9bc3040a

# %% [markdown]
# ## 3 — Finds of a chosen period
#
# Select finds by **geological period**, rolling sub-phases up to their umbrella with
# `hasperiod/skos:broader*`. Change `fairyland:Cretaceous` to `Triassic`, `Jurassic`, or
# `Mesozoic` (the umbrella returns everything).

# %%
PERIOD = "Cretaceous"   # Triassic | Jurassic | Cretaceous | Mesozoic
q_period = PFX + f"""
SELECT ?item ?itemLabel ?geo ?layerLabel WHERE {{
  # ?item fairyland:hasperiod/skos:broader* fairyland:{PERIOD} ;
        a ?cls .
  # ?cls  rdfs:subClassOf fairyland:Find ; rdfs:label ?layerLabel .
  OPTIONAL {{ ?item suni:Name ?itemLabel }}
  # ?item geo:hasGeometry/geo:asWKT ?geo .
}}"""
print(q_period)
map_geo(q_period, colour_by="layerLabel")
# Out:
# PREFIX fairyland: <https://github.com/Research-Squirrel-Engineers/FAIRyland/>
# PREFIX geo:  <http://www.opengis.net/ont/geosparql#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX suni: <http://www.github.com/sparqlunicorn#>
# SELECT ?item ?itemLabel ?geo ?layerLabel WHERE {
#   ?item fairyland:hasperiod/skos:broader* fairyland:Cretaceous ;
#         a ?cls .
#   ?cls  rdfs:subClassOf fairyland:Find ; rdfs:label ?layerLabel .
#   OPTIONAL { ?item suni:Name ?itemLabel }
#   ?item geo:hasGeometry/geo:asWKT ?geo .
# }
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1950770376f6da7b3b38dae081c82135 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&#x27;position:fixed;bottom:20px;left:20px;z-index:9999;background:white;padding:8px 10px;border:1px solid #999;border-radius:4px;font:12px sans-serif&#x27;&gt;&lt;b&gt;layerLabel&lt;/b&gt;&lt;br&gt;&lt;span style=&#x27;color:#8e44ad&#x27;&gt;●&lt;/span&gt; Banana&lt;br&gt;&lt;span style=&#x27;color:#2980b9&#x27;&gt;●&lt;/span&gt; Flat-pack panel&lt;br&gt;&lt;span style=&#x27;color:#f39c12&#x27;&gt;●&lt;/span&gt; Koettbullar (meatball find)&lt;br&gt;&lt;span style=&#x27;color:#c0392b&#x27;&gt;●&lt;/span&gt; Lingonberry jar&lt;br&gt;&lt;span style=&#x27;color:#16a085&#x27;&gt;●&lt;/span&gt; Minion&lt;br&gt;&lt;span style=&#x27;color:#7f8c8d&#x27;&gt;●&lt;/span&gt; Pencil stub&lt;br&gt;&lt;span style=&#x27;color:#27ae60&#x27;&gt;●&lt;/span&gt; Tea light&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1950770376f6da7b3b38dae081c82135&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1950770376f6da7b3b38dae081c82135 = L.map(
#                 &quot;map_1950770376f6da7b3b38dae081c82135&quot;,
#                 {
#                     center: [63.88020142500001, 20.026250040277777],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3c0b0744b38df5b69b9dc00ab53c30d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a3c0b0744b38df5b69b9dc00ab53c30d.addTo(map_1950770376f6da7b3b38dae081c82135);
#
#
#             var circle_marker_784ace48195b03b03637074b79d678cb = L.circleMarker(
#                 [63.8801578, 20.0241358],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7f8c8d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7f8c8d&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1950770376f6da7b3b38dae081c82135);
#
#
#         var popup_19d45c2ec85f91f0aa018cb98754770e = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_4d74ad8e06b43678e5a644a31581d10b = $(`&lt;div id=&quot;html_4d74ad8e06b43678e5a644a31581d10b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#28fa130c-4c84-4817-8b2e-855128e2b44e | itemLabel=Pencil | layerLabel=Pencil stub&lt;/div&gt;`)[0];
#                 popup_19d45c2ec85f91f0aa018cb98754770e.setContent(html_4d74ad8e06b43678e5a644a31581d10b);
#
#
#
#         circle_marker_784ace48195b03b03637074b79d678cb.bindPopup(popup_19d45c2ec85f91f0aa018cb98754770e)
#         ;
#
#
#
#
#             var circle_marker_9bb8e4bffe3cb562c417566ee4d18807 = L.circleMarker(
#                 [63.8804781, 20.0236719],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7f8c8d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7f8c8d&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1950770376f6da7b3b38dae081c82135);
#
#
#         var popup_5650e6b1b7a82cff510adbdddf31cab1 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_18a44fee1ba12e4358eec16b47281f18 = $(`&lt;div id=&quot;html_18a44fee1ba12e4358eec16b47281f18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#a0283553-5bf3-4d5e-8438-1dbfbd55f352 | itemLabel=Pencil | layerLabel=Pencil stub&lt;/div&gt;`)[0];
#                 popup_5650e6b1b7a82cff510adbdddf31cab1.setContent(html_18a44fee1ba12e4358eec16b47281f18);
#
#
#
#         circle_marker_9bb8e4bffe3cb562c417566ee4d18807.bindPopup(popup_5650e6b1b7a82cff510adbdddf31cab1)
#         ;
#
#
#
#
#             var circle_marker_b5a96a237d1206d837b619a61230c351 = L.circleMarker(
#                 [63.8809367, 20.0251658],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#27ae60&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor

# %% [markdown]
# ## 4 — Finds within a chosen trench
#
# Finds recorded in one trench, returned with geometry. Change `fairyland:Trench_C3` to any
# cell `A1…E6`. On a **GeoSPARQL-aware** endpoint the *spatial* form selects whatever falls
# inside the trench polygon directly:
#
# ```sparql
# PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
# SELECT ?item ?geo WHERE {
#   fairyland:Trench_C3 geo:hasGeometry/geo:asWKT ?tWkt .
#   ?item a ?c . ?c rdfs:subClassOf fairyland:Find .
#   ?item geo:hasGeometry/geo:asWKT ?geo .
#   FILTER(geof:sfWithin(?geo, ?tWkt))
# }
# ```
#
# Both bind `?item` + `?geo` and map identically for this dataset.

# %%
TRENCH = "Trench_C3"   # A1 ... E6
q_in_trench = PFX + f"""
SELECT ?item ?itemLabel ?geo ?layerLabel WHERE {{
  # ?item fairyland:hastrench fairyland:{TRENCH} ;
        a ?cls .
  # ?cls  rdfs:subClassOf fairyland:Find ; rdfs:label ?layerLabel .
  OPTIONAL {{ ?item suni:Name ?itemLabel }}
  # ?item geo:hasGeometry/geo:asWKT ?geo .
}}"""
print(q_in_trench)
map_geo(q_in_trench, colour_by="layerLabel", zoom=19)
# Out:
# PREFIX fairyland: <https://github.com/Research-Squirrel-Engineers/FAIRyland/>
# PREFIX geo:  <http://www.opengis.net/ont/geosparql#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX suni: <http://www.github.com/sparqlunicorn#>
# SELECT ?item ?itemLabel ?geo ?layerLabel WHERE {
#   ?item fairyland:hastrench fairyland:Trench_C3 ;
#         a ?cls .
#   ?cls  rdfs:subClassOf fairyland:Find ; rdfs:label ?layerLabel .
#   OPTIONAL { ?item suni:Name ?itemLabel }
#   ?item geo:hasGeometry/geo:asWKT ?geo .
# }
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_670bb2af4d81c4dff73457d965b485bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&#x27;position:fixed;bottom:20px;left:20px;z-index:9999;background:white;padding:8px 10px;border:1px solid #999;border-radius:4px;font:12px sans-serif&#x27;&gt;&lt;b&gt;layerLabel&lt;/b&gt;&lt;br&gt;&lt;span style=&#x27;color:#8e44ad&#x27;&gt;●&lt;/span&gt; Koettbullar (meatball find)&lt;br&gt;&lt;span style=&#x27;color:#2980b9&#x27;&gt;●&lt;/span&gt; Minion&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_670bb2af4d81c4dff73457d965b485bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_670bb2af4d81c4dff73457d965b485bd = L.map(
#                 &quot;map_670bb2af4d81c4dff73457d965b485bd&quot;,
#                 {
#                     center: [63.88011240833334, 20.0259495875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 19,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_605ee6c302ee2eff5c2e403b28f0d95f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_605ee6c302ee2eff5c2e403b28f0d95f.addTo(map_670bb2af4d81c4dff73457d965b485bd);
#
#
#             var circle_marker_85a95e4ba8ebbd48d2d4b573093c0b14 = L.circleMarker(
#                 [63.8801926, 20.0258845],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2980b9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2980b9&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_670bb2af4d81c4dff73457d965b485bd);
#
#
#         var popup_a905ca7be1492550ad5c64d787f4541e = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_9228255d6e38836790a1e5f5471e8ad7 = $(`&lt;div id=&quot;html_9228255d6e38836790a1e5f5471e8ad7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#26551278-d0f1-4741-950e-47e88d0bfcef | itemLabel=Minions | layerLabel=Minion&lt;/div&gt;`)[0];
#                 popup_a905ca7be1492550ad5c64d787f4541e.setContent(html_9228255d6e38836790a1e5f5471e8ad7);
#
#
#
#         circle_marker_85a95e4ba8ebbd48d2d4b573093c0b14.bindPopup(popup_a905ca7be1492550ad5c64d787f4541e)
#         ;
#
#
#
#
#             var polygon_8d3866cf598f31844c43f44648abcb2e = L.polygon(
#                 [[63.8800177, 20.0257186], [63.8800177, 20.0257717], [63.8800303, 20.0257717], [63.8800303, 20.0257186], [63.8800177, 20.0257186]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_670bb2af4d81c4dff73457d965b485bd);
#
#
#         var popup_f8de54e9ed8aa45a7c52242520274e13 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_434bbb00c67a9dfe66a10b054caca0a2 = $(`&lt;div id=&quot;html_434bbb00c67a9dfe66a10b054caca0a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#28ec2dbf-6806-4a32-a35d-78764bfda459 | itemLabel=Kötbullar | layerLabel=Koettbullar (meatball find)&lt;/div&gt;`)[0];
#                 popup_f8de54e9ed8aa45a7c52242520274e13.setContent(html_434bbb00c67a9dfe66a10b054caca0a2);
#
#
#
#         polygon_8d3866cf598f31844c43f44648abcb2e.bindPopup(popup_f8de54e9ed8aa45a7c52242520274e13)
#         ;
#
#
#
#
#             var circle_marker_a796e2d58c377e0800c8147f470000d2 = L.circleMarker(
#                 [63.8801047, 20.0258968],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;we

# %% [markdown]
# ## Explore
#
# Every map above came from one `SELECT … ?item … ?geo`. Combine the patterns — e.g.
# *Cretaceous bananas only* — and the result still binds `?item` + `?geo`, so it maps here
# and loads as a QGIS layer in the Unicorn plugin. Edit and re-run:

# %%
q_custom = PFX + """
SELECT ?item ?geo WHERE {
  # ?item a fairyland:Banana ;
        fairyland:hasperiod/skos:broader* fairyland:Cretaceous ;
        geo:hasGeometry/geo:asWKT ?geo .
}"""
print(q_custom)
map_geo(q_custom)
# Out:
# PREFIX fairyland: <https://github.com/Research-Squirrel-Engineers/FAIRyland/>
# PREFIX geo:  <http://www.opengis.net/ont/geosparql#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX suni: <http://www.github.com/sparqlunicorn#>
# SELECT ?item ?geo WHERE {
#   ?item a fairyland:Banana ;
#         fairyland:hasperiod/skos:broader* fairyland:Cretaceous ;
#         geo:hasGeometry/geo:asWKT ?geo .
# }
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1cae28fdffae29fb0f0b3818369ad2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1cae28fdffae29fb0f0b3818369ad2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1cae28fdffae29fb0f0b3818369ad2c = L.map(
#                 &quot;map_a1cae28fdffae29fb0f0b3818369ad2c&quot;,
#                 {
#                     center: [63.88059894285714, 20.02663927142857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b32160aa64ea45a6fbda68ab9d84ac6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b32160aa64ea45a6fbda68ab9d84ac6e.addTo(map_a1cae28fdffae29fb0f0b3818369ad2c);
#
#
#             var circle_marker_4ef3e5ef910b47387337d8c533732df5 = L.circleMarker(
#                 [63.8804931, 20.0287754],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1cae28fdffae29fb0f0b3818369ad2c);
#
#
#         var popup_c37c1eb9cb4680a34d2cc5a287345ba9 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_b5b37669d13a2b0b5321fbd277db7565 = $(`&lt;div id=&quot;html_b5b37669d13a2b0b5321fbd277db7565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#20e35462-2580-f6e0-f297-4b212dc76bc5&lt;/div&gt;`)[0];
#                 popup_c37c1eb9cb4680a34d2cc5a287345ba9.setContent(html_b5b37669d13a2b0b5321fbd277db7565);
#
#
#
#         circle_marker_4ef3e5ef910b47387337d8c533732df5.bindPopup(popup_c37c1eb9cb4680a34d2cc5a287345ba9)
#         ;
#
#
#
#
#             var circle_marker_af897216d0cbbf689162b78f4db22a04 = L.circleMarker(
#                 [63.8806411, 20.027025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1cae28fdffae29fb0f0b3818369ad2c);
#
#
#         var popup_00c6a0183097ad5360f21abb3e49798d = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_f14ad2e19a5404fa0f435477c44c3524 = $(`&lt;div id=&quot;html_f14ad2e19a5404fa0f435477c44c3524&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#2a6e27ff-96d7-c446-0392-7c39fb34b9d4&lt;/div&gt;`)[0];
#                 popup_00c6a0183097ad5360f21abb3e49798d.setContent(html_f14ad2e19a5404fa0f435477c44c3524);
#
#
#
#         circle_marker_af897216d0cbbf689162b78f4db22a04.bindPopup(popup_00c6a0183097ad5360f21abb3e49798d)
#         ;
#
#
#
#
#             var circle_marker_b7c7dfa88804c9f244fe1b79734b6935 = L.circleMarker(
#                 [63.8806643, 20.0248265],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8e44ad&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8e44ad&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1cae28fdffae29fb0f0b3818369ad2c);
#
#
#         var popup_56964e62f83e0e9e7a7cedfe95b3e717 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_519a87c5cb274723c0594c1ecccc079c = $(`&lt;div id=&quot;html_519a87c5cb274723c0594c1ecccc079c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;item=http://www.github.com/sparqlunicorn#36510cec-f627-1951-d6f8-1b0def35b77a&lt;/div&gt;`)[0];
#                 popup_56964e62f83e0e9e7a7cedfe95b3e717.setContent(html_519a87c5cb274723c0594c1ecccc079c);
#
#
#
#         circle_ma

# %% [markdown]
# ---
#
# *Part of the NFDI4Objects Open Educational Resources. Dataset: FAIRyland (fictional),
# Research Squirrel Engineers Network, CC BY 4.0. Local Jupyter variant; a browser-executable
# Quarto Live (`.qmd`) companion accompanies it in the OER.*
